# %%
import pandas as pd
import numpy as nm
import matplotlib.pyplot as plt
import seaborn as sb
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## DATA CLEANING AND LOADING

# %%
df =pd.read_csv("../Datasets/HR_Attrition.csv")
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %% [markdown]
# ## CHECKING DATATYPES

# %%
df.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %% [markdown]
# ## FINDING NULL VALUES

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %% [markdown]
# ## STATISTICS ANALYSIS

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %% [markdown]
# ## DISCRIPTIVE ANALYSIS

# %%
df.Age.unique()
# Out:
# array([41, 49, 37, 33, 27, 32, 59, 30, 38, 36, 35, 29, 31, 34, 28, 22, 53,
#        24, 21, 42, 44, 46, 39, 43, 50, 26, 48, 55, 45, 56, 23, 51, 40, 54,
#        58, 20, 25, 19, 57, 52, 47, 18, 60], dtype=int64)

# %%
df.Attrition.unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df.Department.unique()
# Out:
# array(['Sales', 'Research & Development', 'Human Resources'], dtype=object)

# %%
df.JobRole.unique()
# Out:
# array(['Sales Executive', 'Research Scientist', 'Laboratory Technician',
#        'Manufacturing Director', 'Healthcare Representative', 'Manager',
#        'Sales Representative', 'Research Director', 'Human Resources'],
#       dtype=object)

# %%
sb.barplot(x=df.Attrition,y=df.MonthlyIncome,palette='Set3')
plt.title("Attrition v/s Monthly Income")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #### The Monthly Salary of existing employees is greater than the laid off employees is representing using bargraph,
# #### The max salary of existing employees is 7000 and
# #### The max salary of laid off employees is approxe 5000

# %%
sb.countplot(x=df.Department,palette="spring")
plt.title("Distribution of employees across  Department")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #### Majoraty of employees are in research and development department followed by sales and humun resource

# %%
sb.countplot(x=df.JobRole,palette="Set2")
plt.title("Distribution of employees across  Department")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #### The most common Job Role is sales executive with 362 employees

# %%
sb.histplot(df.MonthlyIncome,color='Green')
plt.show()

# %% [markdown]
# #### The distribution may show a right skewed pattern with a small number of employees earning highest salary

# %%
sb.histplot(df.Age,color='orange')
plt.show()

# %% [markdown]
# #### Peaks in certain age range of 30 to 40 might indicate a concentration of employees in specific career stages.

# %%
correlation_matrix=df.corr(numeric_only=True)
correlation_matrix
# Out:
#                                Age  DailyRate  DistanceFromHome  Education  \
# Age                       1.000000   0.010661         -0.001686   0.208034
# DailyRate                 0.010661   1.000000         -0.004985  -0.016806
# DistanceFromHome         -0.001686  -0.004985          1.000000   0.021042
# Education                 0.208034  -0.016806          0.021042   1.000000
# EmployeeCount                  NaN        NaN               NaN        NaN
# EmployeeNumber           -0.010145  -0.050990          0.032916   0.042070
# EnvironmentSatisfaction   0.010146   0.018355         -0.016075  -0.027128
# HourlyRate                0.024287   0.023381          0.031131   0.016775
# JobInvolvement            0.029820   0.046135          0.008783   0.042438
# JobLevel                  0.509604   0.002966          0.005303   0.101589
# JobSatisfaction          -0.004892   0.030571         -0.003669  -0.011296
# ...

# %%
plt.figure(figsize=(16,12))
sb.heatmap(correlation_matrix,annot=True,cmap='Set1',fmt='.2f',cbar=True)
plt.title('Correlation_Matrix')
plt.show()

# %% [markdown]
# #### The job level and Monthly income of employees are showing perfect positive Relation and
# #### this job level are showing strong relation with total working year of employees also
# #### show moderate relation with age.
# #### The Age and Total Working Year of employees are showing strong positive relation.

# %%
plt.figure(figsize=(22,6))
plt.subplot(1,3,1)
sb.boxplot(x=df.Attrition ,y=df.JobSatisfaction,palette='hot')

plt.subplot(1,3,2)
sb.boxplot(x=df.Attrition ,y=df.PerformanceRating,palette='spring')

plt.subplot(1,3,3)
sb.boxplot(x=df.Attrition ,y=df.MonthlyIncome,palette='deep')
plt.show()

# %% [markdown]
# #### Employees with lower job satisfaction (closer to 1) are more likely to leave the company, as shown by the distribution for "Attrition = Yes."
# #### Higher job satisfaction (closer to 4) is associated with employees who stay ("Attrition = No"), suggesting that improving job satisfaction could reduce attrition rates.

# %%
plt.figure(figsize=(16,5))
plt.subplot(1,3,1)
sb.countplot(data=df,x='Department',hue='Attrition')

plt.subplot(1,3,2)
sb.countplot(data=df,x='EducationField',hue='Attrition')
plt.xticks(rotation=90)

plt.subplot(1,3,3)
sb.histplot(data=df, x='Age', hue='Attrition', multiple="stack")
plt.show()

# %% [markdown]
# #### DEPARTMENT
# #### >The Research &Development department has the highest number of employees followed by Sales and Human Resources.
#
# #### EDUCATIONFIELD
# #### >Life Science is the most common education field among employees,the highest among all fields
#
# #### Age
# #### >The distribution of age typically shows that most employees are concentrated in their 30s and early 40s, representing mid-career professionals.
# #### >Younger employees (in their 20s) and older employees (50+) may form smaller portions, highlighting possible gaps in workforce demographics.
