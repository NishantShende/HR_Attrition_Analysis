# %%
import pandas as pd
import numpy as nm
import matplotlib.pyplot as plt
import seaborn as sb

# %% [markdown]
# #Data Cleaning and Loading

# %%
df =pd.read_csv("../Datasets/HR_Attrition.csv")
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
df.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
df.Age.unique()
# Out:
# array([41, 49, 37, 33, 27, 32, 59, 30, 38, 36, 35, 29, 31, 34, 28, 22, 53,
#        24, 21, 42, 44, 46, 39, 43, 50, 26, 48, 55, 45, 56, 23, 51, 40, 54,
#        58, 20, 25, 19, 57, 52, 47, 18, 60], dtype=int64)

# %%
There are 43 unique values in Age

# %%
df.Attrition.unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
There are 2 unique values in Attrition

# %%
df.Department.unique()
# Out:
# array(['Sales', 'Research & Development', 'Human Resources'], dtype=object)

# %%
There are 3 unique values in Department

# %%
df.JobRole.unique()
# Out:
# array(['Sales Executive', 'Research Scientist', 'Laboratory Technician',
#        'Manufacturing Director', 'Healthcare Representative', 'Manager',
#        'Sales Representative', 'Research Director', 'Human Resources'],
#       dtype=object)

# %%
sb.barplot(x=df.Attrition,y=df.MonthlyIncome)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# The Monthly Salary of existing employees is greater than the laid off employees is representing using bargraph,
# The max salary of existing employees is 7000 and
# The max salary of laid off employees is approxe 5000

# %%
sb.barplot(x=df.JobRole,y=df.MonthlyIncome)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# The Monthly Salary of manager is the highest salary in Job Role
# The Monthly salary of Sales Representive is the lowest salary in Job Role

# %%
sb.barplot(x=df.Attrition,y=df.JobSatisfaction)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# The job satisfaction ratio according to the employees attrition for both Yes And No.
# the satisfaction rating of existing employees is greater that is approximetly 3

# %%
sb.barplot(x=df.Attrition,y=df.RelationshipSatisfaction)
plt.xticks(rotation=90)
plt.show()

# %%
Showing graph for the relation of  Atrition v/s Relationship Satisfaction. The Attrition for both yes  and No are distributed normally.

# %%
sb.lineplot(x=df.Age,y=df.Attrition,c="r")
plt.show()

# %%
Showing graph for the relation of Age v/s Atrition with respect to their genders. Ant the Ages for both male and gender are distributed normally.

# %%
sb.histplot(df.MonthlyIncome)
plt.show()

# %%
sb.histplot(df.Age)
plt.show()

# %%
correlation_matrix=df.corr(numeric_only=True)
correlation_matrix
# Out:
#                                Age  DailyRate  DistanceFromHome  Education  \
# Age                       1.000000   0.010661         -0.001686   0.208034
# DailyRate                 0.010661   1.000000         -0.004985  -0.016806
# DistanceFromHome         -0.001686  -0.004985          1.000000   0.021042
# Education                 0.208034  -0.016806          0.021042   1.000000
# EmployeeCount                  NaN        NaN               NaN        NaN
# EmployeeNumber           -0.010145  -0.050990          0.032916   0.042070
# EnvironmentSatisfaction   0.010146   0.018355         -0.016075  -0.027128
# HourlyRate                0.024287   0.023381          0.031131   0.016775
# JobInvolvement            0.029820   0.046135          0.008783   0.042438
# JobLevel                  0.509604   0.002966          0.005303   0.101589
# JobSatisfaction          -0.004892   0.030571         -0.003669  -0.011296
# ...

# %%
plt.figure(figsize=(16,12))
sb.heatmap(correlation_matrix,annot=True,cmap='Set1',fmt='.2f',cbar=True)
plt.title('Correlation_Matrix')
plt.show()

# %% [markdown]
# PercentSalaryHike,PerformanceRating are colinear 77%.
#
# JobLevel,TotalWorkingYears are collinear 78%.
#
# JobLevel,MonthlyIncome are collinear 95%.
#
# TotalWorkingYears,MonthlyIncome are collinear 77%.
#
# YearsAtCompany are collinear with YearsInCurrentRole and YearsWithCurrManager i.e. 76% and 77%
#
# YearsInCurrentRole is collinear with YearsWithCurrManager i.e. 71%.

# %%
y=df[df.Attrition=='Yes']
y
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 14     28       Yes      Travel_Rarely        103  Research & Development
# 21     36       Yes      Travel_Rarely       1218                   Sales
# 24     34       Yes      Travel_Rarely        699  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1438   23       Yes  Travel_Frequently        638                   Sales
# 1442   29       Yes      Travel_Rarely       1092  Research & Development
# 1444   56       Yes      Travel_Rarely        310  Research & Development
# 1452   50       Yes  Travel_Frequently        878                   Sales
# 1461   50       Yes      Travel_Rarely        410                   Sales
#
#       DistanceFromHome  Education    EducationField  EmployeeCount  \
# ...

# %%
n=df[df.Attrition=='No']
n
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1      49        No  Travel_Frequently        279  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# 5      32        No  Travel_Frequently       1005  Research & Development
# 6      59        No      Travel_Rarely       1324  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
plt.figure(figsize=(22,6))
plt.subplot(1,3,1)
sb.boxplot(x=df.Attrition ,y=df.JobSatisfaction,palette='hot')

plt.subplot(1,3,2)
sb.boxplot(x=df.Attrition ,y=df.PerformanceRating,palette='spring')

plt.subplot(1,3,3)
sb.boxplot(x=df.Attrition ,y=df.MonthlyIncome,palette='deep')
plt.show()
# Out:
# C:\Users\user8\AppData\Local\Temp\ipykernel_11440\4242155907.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sb.boxplot(x=df.Attrition ,y=df.JobSatisfaction,palette='hot')
# C:\Users\user8\AppData\Local\Temp\ipykernel_11440\4242155907.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sb.boxplot(x=df.Attrition ,y=df.PerformanceRating,palette='spring')
# C:\Users\user8\AppData\Local\Temp\ipykernel_11440\4242155907.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sb.boxplot(x=df.Attrition ,y=df.MonthlyIncome,palette='deep')

# %%
plt.figure(figsize=(16,5))
plt.subplot(1,4,1)
sb.countplot(data=df,x='Department',hue='Attrition')

plt.subplot(1,4,2)
sb.countplot(data=df,x='Age',hue='Attrition')
plt.xticks(rotation=90)

plt.subplot(1,4,3)
sb.countplot(data=df,x='EducationField',hue='Attrition')
plt.xticks(rotation=90)

plt.subplot(1,4,4)
sb.histplot(data=df, x='Age', hue='Attrition', multiple="stack")
plt.show()

# %%
df.groupby("Department")['PerformanceRating'].max().nlargest()
# Out:
# Department
# Human Resources           4
# Research & Development    4
# Sales                     4
# Name: PerformanceRating, dtype: int64

# %%
df.groupby("EmployeeNumber")['PerformanceRating'].max().nlargest(10)
# Out:
# EmployeeNumber
# 2     4
# 10    4
# 11    4
# 12    4
# 27    4
# 33    4
# 57    4
# 60    4
# 61    4
# 62    4
# Name: PerformanceRating, dtype: int64

# %%
df.groupby("JobRole")['JobSatisfaction'].max().nlargest()
# Out:
# JobRole
# Healthcare Representative    4
# Human Resources              4
# Laboratory Technician        4
# Manager                      4
# Manufacturing Director       4
# Name: JobSatisfaction, dtype: int64

# %%
df.groupby("Department")['JobSatisfaction'].max().nlargest()
# Out:
# Department
# Human Resources           4
# Research & Development    4
# Sales                     4
# Name: JobSatisfaction, dtype: int64

# %%
df.groupby("JobRole")['RelationshipSatisfaction'].max().nlargest()
# Out:
# JobRole
# Healthcare Representative    4
# Human Resources              4
# Laboratory Technician        4
# Manager                      4
# Manufacturing Director       4
# Name: RelationshipSatisfaction, dtype: int64

# %%
df.groupby("Department")['RelationshipSatisfaction'].max().nlargest(10)
# Out:
# Department
# Human Resources           4
# Research & Development    4
# Sales                     4
# Name: RelationshipSatisfaction, dtype: int64

# %%
df.groupby("Department")['MonthlyIncome'].max().nlargest()
# Out:
# Department
# Research & Development    19999
# Sales                     19847
# Human Resources           19717
# Name: MonthlyIncome, dtype: int64

# %%
pd.crosstab(index=df.Department,columns=df.Attrition,margins=True)
# Out:
# Attrition                 No  Yes   All
# Department
# Human Resources           51   12    63
# Research & Development   828  133   961
# Sales                    354   92   446
# All                     1233  237  1470

# %%
pd.crosstab(index=df.Gender,columns=df.Attrition,margins=True)
# Out:
# Attrition    No  Yes   All
# Gender
# Female      501   87   588
# Male        732  150   882
# All        1233  237  1470

# %%
pd.crosstab(index=df.Attrition,columns=df.JobRole,margins=True)
# Out:
# JobRole    Healthcare Representative  Human Resources  Laboratory Technician  \
# Attrition
# No                               122               40                    197
# Yes                                9               12                     62
# All                              131               52                    259
#
# JobRole    Manager  Manufacturing Director  Research Director  \
# Attrition
# No              97                     135                 78
# Yes              5                      10                  2
# All            102                     145                 80
#
# JobRole    Research Scientist  Sales Executive  Sales Representative   All
# Attrition
# No                        245              269                    50  1233
# Yes                        47               57                    33   237
# All                       292              326                    83  1470

# %%
f=y.Department.value_counts()
f
# Out:
# Department
# Research & Development    133
# Sales                      92
# Human Resources            12
# Name: count, dtype: int64

# %%
plt.pie(f.values,labels=f.index,autopct='%d%%')
plt.show()

# %%
t=n.Department.value_counts()
t
# Out:
# Department
# Research & Development    828
# Sales                     354
# Human Resources            51
# Name: count, dtype: int64

# %%
plt.pie(t.values,labels=t.index,autopct='%d%%')
plt.show()

# %%
c=y.Gender.value_counts()
c
# Out:
# Gender
# Male      150
# Female     87
# Name: count, dtype: int64

# %%
plt.pie(c.values,labels=c.index,autopct='%d%%')
plt.show()
